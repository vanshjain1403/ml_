# %%
import pandas as pd

# %% [markdown]
# #Working with JSON

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWG  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ZWG  https://www.exchangerate-api.com/docs/free
# ZWL  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# INR  https://www.exchangerate-api.com/terms  INR 2026-01-24
# AED  https://www.exchangerate-api.com/terms  INR 2026-01-24
# AFN  https://www.exchangerate-api.com/terms  INR 2026-01-24
# ALL  https://www.exchangerate-api.com/terms  INR 2026-01-24
# AMD  https://www.exchangerate-api.com/terms  INR 2026-01-24
# ..                                      ...  ...        ...
# YER  https://www.exchangerate-api.com/terms  INR 2026-01-24
# ZAR  https://www.exchangerate-api.com/terms  INR 2026-01-24
# ZMW  https://www.exchangerate-api.com/terms  INR 2026-01-24
# ZWG  https://www.exchangerate-api.com/terms  INR 2026-01-24
# ZWL  https://www.exchangerate-api.com/terms  INR 2026-01-24
#
#      time_last_updated  rates
# INR         1769212802  1.000
# AED         1769212802  0.040
# AFN         1769212802  0.720
# ALL         1769212802  0.900
# AMD         1769212802  4.120
# ..                 ...    ...
# YER         1769212802  2.600
# ZAR         1769212802  0.176
# ZMW         1769212802  0.215
# ZWG         1769212802  0.279
# ZWL         1769212802  0.279
#
# [166 rows x 7 columns]

# %% [markdown]
# #Working with SQL

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host="localhost",user="root",password ='',database='World')

# %%
pd.read_sql_query("SELECT * FROM CITY WHERE CountryCode LIKE 'IND'",conn)
# Out:
# C:\Users\jainv\AppData\Local\Temp\ipykernel_10116\2064288537.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM CITY WHERE CountryCode LIKE 'IND'",conn)
#        ID                Name CountryCode        District  Population
# 0    1024     Mumbai (Bombay)         IND     Maharashtra    10500000
# 1    1025               Delhi         IND           Delhi     7206704
# 2    1026  Calcutta [Kolkata]         IND    West Bengali     4399819
# 3    1027    Chennai (Madras)         IND      Tamil Nadu     3841396
# 4    1028           Hyderabad         IND  Andhra Pradesh     2964638
# ..    ...                 ...         ...             ...         ...
# 336  1360        Ambala Sadar         IND         Haryana       90712
# 337  1361          Baidyabati         IND    West Bengali       90601
# 338  1362               Morvi         IND         Gujarat       90357
# 339  1363             Raigarh         IND     Chhatisgarh       89166
# 340  1364            Vejalpur         IND         Gujarat       89053
#
# [341 rows x 5 columns]

# %%
pd.read_sql_query("SELECT * FROM COUNTRY WHERE LifeExpectancy > 70 ",conn)
# Out:
# C:\Users\jainv\AppData\Local\Temp\ipykernel_10116\3567020279.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM COUNTRY WHERE LifeExpectancy > 70 ",conn)
#     Code                              Name      Continent           Region  \
# 0    ABW                             Aruba  North America        Caribbean
# 1    AIA                          Anguilla  North America        Caribbean
# 2    ALB                           Albania         Europe  Southern Europe
# 3    AND                           Andorra         Europe  Southern Europe
# 4    ANT              Netherlands Antilles  North America        Caribbean
# ..   ...                               ...            ...              ...
# 106  VCT  Saint Vincent and the Grenadines  North America        Caribbean
# 107  VEN                         Venezuela  South America    South America
# 108  VGB           Virgin Islands, British  North America        Caribbean
# 109  VIR              Virgin Islands, U.S.  North America        Caribbean
# 110  YUG                        Yugoslavia         Europe  Southern Europe
#
#      SurfaceArea  IndepYear  Population  LifeExpectancy      GNP   GNPOld  \
# 0          193.0        NaN      103000            78.4    828.0    793.0
# 1           96.0        NaN        8000            76.1     63.2      NaN
# 2        28748.0     1912.0     3401200            71.6   3205.0   2500.0
# 3          468.0     1278.0       78000            83.5   1630.0      NaN
# 4          800.0        NaN      217000            74.7   1941.0      NaN
# ..           ...        ...         ...             ...      ...      ...
# 106        388.0     1979.0      114000            72.3    285.0      NaN
# 107     912050.0     1811.0    24170000            73.1  95023.0  88434.0
# 108        151.0        NaN       21000            75.4    612.0    573.0
# 109        347.0        NaN       93000            78.1      0.0      NaN
# 110     102173.0     1918.0    10640000            72.4  17000.0      NaN
#
#                                LocalName  \
# 0                                  Aruba
# 1                               Anguilla
# 2                              Shqipëria
# 3                                Andorra
# 4                   Nederlandse Antillen
# ..                                   ...
# 106     Saint Vincent and the Grenadines
# 107                            Venezuela
# 108               British Virgin Islands
# 109  Virgin Islands of the United States
# 110                          Jugoslavija
#
#                                    GovernmentForm         HeadOfState  \
# 0    Nonmetropolitan Territory of The Netherlands             Beatrix
# 1                   Dependent Territory of the UK        Elisabeth II
# 2                                        Republic      Rexhep Mejdani
# 3                    Parliamentary Coprincipality
# 4    Nonmetropolitan Territory of The Netherlands             Beatrix
# ..                                            ...                 ...
# 106                       Constitutional Monarchy        Elisabeth II
# 107                              Federal Republic   Hugo Chávez Frías
# 108                 Dependent Territory of the UK        Elisabeth II
# 109                                  US Territory      George W. Bush
# 110                              Federal Republic  Vojislav Koštunica
#
#      Capital Code2
# 0        129    AW
# 1         62    AI
# 2         34    AL
# 3         55    AD
# 4         33    AN
# ..       ...   ...
# 106     3066    VC
# 107     3539    VE
# 108      537    VG
# 109     4067    VI
# 110     1792    YU
#
# [111 rows x 15 columns]

# %%
df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)
# Out:
# C:\Users\jainv\AppData\Local\Temp\ipykernel_10116\4272969784.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)

# %%
df
# Out:
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]
