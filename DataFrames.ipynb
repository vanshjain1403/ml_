# %%
import numpy as np
import pandas as pd

# %%
data={
    "Name":["Vansh","Aagman","Hemang","Krishna","Harsh"],
    "Age":[21,20,20,21,21],
    "City":["SRE","KPR","DDN","DDN","BKR"],
    "Salary":[10000000,7000000,6000000,5000000,9000000]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age City    Salary
# 0    Vansh   21  SRE  10000000
# 1   Aagman   20  KPR   7000000
# 2   Hemang   20  DDN   6000000
# 3  Krishna   21  DDN   5000000
# 4    Harsh   21  BKR   9000000

# %%
data1=[
   
    ['Vansh', 21, 'SRE', 10000000],
    ['Aagman', 20, 'KPR', 7000000],
    ['Hemang', 20, 'DDN', 6000000],
    ['Krishna', 21, 'DDN', 5000000],
    ['Harsh', 21, 'BKR', 9000000]
]

# %%
df2 = pd.DataFrame(data1)

# %%
df2
# Out:
#          0   1    2         3
# 0    Vansh  21  SRE  10000000
# 1   Aagman  20  KPR   7000000
# 2   Hemang  20  DDN   6000000
# 3  Krishna  21  DDN   5000000
# 4    Harsh  21  BKR   9000000

# %%
columns = ["Name","Age","City","Salary"]

# %%
df2 = pd.DataFrame(data1,columns=columns)

# %%
df2
# Out:
#       Name  Age City    Salary
# 0    Vansh   21  SRE  10000000
# 1   Aagman   20  KPR   7000000
# 2   Hemang   20  DDN   6000000
# 3  Krishna   21  DDN   5000000
# 4    Harsh   21  BKR   9000000

# %%
df2.loc[0]
# Out:
# Name         Vansh
# Age             21
# City           SRE
# Salary    10000000
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#      Name  Age City    Salary
# 0   Vansh   21  SRE  10000000
# 1  Aagman   20  KPR   7000000

# %%
df2.iloc[3]
# Out:
# Name      Krishna
# Age            21
# City          DDN
# Salary    5000000
# Name: 3, dtype: object

# %% [markdown]
# SELECTING SUBSETS OF ROWS AND COLUMNS

# %%
df2.loc[[0,1]][["City","Salary"]]
# Out:
#   City    Salary
# 0  SRE  10000000
# 1  KPR   7000000

# %%
df2.iloc[[2,3]][["Name","Age"]]
# Out:
#       Name  Age
# 2   Hemang   20
# 3  Krishna   21

# %% [markdown]
# CONDITIONAL SELECTION

# %%
df2[(df2["Age"]>20) & (df2["City"]=="SRE")]
# Out:
#     Name  Age City    Salary
# 0  Vansh   21  SRE  10000000
