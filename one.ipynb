# %%
a = 12
print("hello")
# Out:
# hello

# %%
print("how are you?")
# Out:
# how are you?

# %%
def hello():
    print("hey how are you")

# %%
hello()
# Out:
# hey how are you

# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
