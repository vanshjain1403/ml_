# %%
import pandas as pd
import numpy as np

# %%
labels = ["a","b","c"]
my_list = [10,20,30]
my_array = np.array([10,20,30])
d = {1:10,2:20,3:30}

# %%
pd.Series(my_list,index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_array,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
